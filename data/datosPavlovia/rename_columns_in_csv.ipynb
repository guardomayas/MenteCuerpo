# %%
import os 
import pandas as pd

def rename_columns_in_csv(folder_path):
    #Uses os.listdir to get a list of all files in the folder that end with '.csv'.
    csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')] #This is just in case we have .log files or other kind of stuhhds
    
    #it iterates through each CSV file and reads it 
    for file_name in csv_files:
        file_path = os.path.join(folder_path, file_name)
        
        # Check if the file is empty or contains only a single row
        with open(file_path, 'r') as file:   # The with statement is used to open the file specified by file_path in read mode ('r'). The with statement ensures that the file is properly closed after it's done being used
            first_line = file.readline().strip() #reads the first line of the file and strips any leading or trailing whitespace (including newline characters). This is done to check if the first line is empty or contains only whitespa
            if not first_line:
                print(f"Skipping empty file: {file_name}")
                continue
        data = pd.read_csv(file_path)
        
        old_cols = ['ss_Amt', 'ss_Delay', 'll_Amt', 'll_Delay']
        new_cols = ['ss_am', 'ss_del', 'll_am', 'll_del']
        
        for old_col, new_col in zip(old_cols, new_cols): #Zip function iterates through 2 lists. That's so cool!
            if old_col in data.columns:
                data.rename(columns={old_col: new_col}, inplace=True)
        
        data.to_csv(file_path, index=False)

# Specify the folder path where your CSV files are located

# %%
folder_path = '/Users/guardomayas2/Matlab/MindBody/data/datosPavlovia'
rename_columns_in_csv(folder_path)
# Out:
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-09-07_09h05.08.952.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_08h29.06.967.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-11-24_07h48.11.472.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-08-05_17h45.44.842.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_09h20.07.079.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_08h04.58.259.csv
# Skipping empty file: 78_tareaTDv3_2020-11-13_09h52.58.394.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-09-07_08h33.05.695.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_08h52.14.694.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_09h20.02.049.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-08-06_08h13.09.155.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-09-07_07h24.14.223.csv
# Skipping empty file: 270_tareaTDv3_2020-11-12_11h34.55.275.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-11-09_19h20.40.138.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2020-11-12_09h32.23.817.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2020-11-12_11h18.38.055.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_09h39.51.180.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-09-07_08h49.38.514.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-07-25_16h33.35.341.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2021-11-13_07h18.57.518.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2020-11-12_11h41.26.285.csv
# Skipping empty file: 220_tareaTDv3_2020-11-12_11h20.33.640.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-09-07_07h35.57.299.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-04_12h21.24.207.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_09h06.05.391.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_08h29.43.596.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-08-05_10h21.54.295.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2020-11-12_13h48.07.266.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_08h20.07.448.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_09h39.19.603.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-05-03_18h29.40.564.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_09h39.51.960.csv
# Skipping empty file: 318_tareaTDv3_2020-11-11_11h28.21.802.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_09h39.55.072.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-08-04_14h05.43.273.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_09h06.08.510.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-02-07_16h39.41.485.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-09-07_09h08.39.743.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2020-11-18_11h57.13.721.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-05-05_14h28.43.692.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_08h29.17.452.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2020-11-12_11h56.20.053.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_09h39.20.623.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022-03-05_09h06.10.475.csv
# Skipping empty file: PARTICIPANT_Rosario_dd_2022